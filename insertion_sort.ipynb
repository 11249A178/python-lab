# %% [markdown]
# <a href="https://colab.research.google.com/github/11249A178/python-lab/blob/main/insertion_sort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Store the question in a string
Q71 = "7.1. Write a Python program to implement insertion sort using lists."
print(Q71)

# Insertion Sort Implementation
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1

        # Move elements greater than key one position ahead
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1

        arr[j + 1] = key

# Input from user
numbers = list(map(int, input("Enter numbers separated by spaces: ").split()))

print("Original list:", numbers)
insertion_sort(numbers)
print("Sorted list:", numbers)
# Out:
# 7.1. Write a Python program to implement insertion sort using lists.
# Enter numbers separated by spaces: 5
# Original list: [5]
# Sorted list: [5]
