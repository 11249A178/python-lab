# %% [markdown]
# <a href="https://colab.research.google.com/github/11249A178/python-lab/blob/main/palindrome_count.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to check if a number is palindrome
def is_palindrome(number):
    num_str = str(number)
    return num_str == num_str[::-1]

# Function to count frequency of each digit
def count_digit_frequency(number):
    num_str = str(number)
    freq = {}
    for digit in num_str:
        freq[digit] = freq.get(digit, 0) + 1
    return freq

# Main program
num = int(input("Enter a number: "))

# Check palindrome
if is_palindrome(num):
    print(f"{num} is a palindrome.")
else:
    print(f"{num} is not a palindrome.")

# Count digit frequency
frequency = count_digit_frequency(num)
print("\nDigit frequencies:")
for digit, count in sorted(frequency.items()):
    print(f"Digit {digit}: {count}")
# Out:
# Enter a number: 5
# 5 is a palindrome.
#
# Digit frequencies:
# Digit 5: 1
